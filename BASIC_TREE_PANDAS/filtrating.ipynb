# %%
import numpy as np
import pandas as pd

student_perfomance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
student_perfomance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
arr = []
for i in range(1000):
    if i % 2 == 0:
        arr.append(True) 
    else:
        arr.append(False)
student_perfomance.loc[arr]
student_perfomance.loc[(student_perfomance.gender == 'female') & (student_perfomance.lunch == 'standard'), 
                       ['gender','writing score']
]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 984  female             82
# 986  female             51
# 991  female             78
# 995  female             95
# 998  female             77
#
# [329 rows x 2 columns]

# %%
writing_mean = student_perfomance['writing score'].mean()
student_perfomance.loc[student_perfomance['writing score'] > writing_mean]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_perfomance.loc[student_perfomance['writing score'] > writing_mean]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_perfomance.loc[student_perfomance.lunch ==  "free/reduced"].shape[0] / student_perfomance.shape[0]
# Out:
# 0.355

# %%
print('Standard lunch')
student_perfomance.loc[student_perfomance.lunch == 'standard',['math score', 'reading score', 'writing score']].mean()
# Out:
# Standart lunch
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
student_perfomance.loc[student_perfomance.lunch == 'standard',['math score', 'reading score', 'writing score']].var()
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %%
print('reduced lunch')
student_perfomance.loc[student_perfomance.lunch == 'free/reduced',['math score', 'reading score', 'writing score']].mean()
# Out:
# reduced lunch
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
student_perfomance.loc[student_perfomance.lunch == 'free/reduced',['math score', 'reading score', 'writing score']].var()
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
# QUERY and RENAIMG

subset_1 = my_stat.query('V1 > 0 & V3 == "A"')

# %%
mean_level = 90
student_perfomance = student_perfomance.rename(columns = {
    "parental level of education" : "parental_level_of_education",
    "test preparation course" : "test_preparation_course",
    "math score" : "math_score", "reading score" : "reading_score",
    "writing score" : "writing_score"
})
student_perfomance.query("math_score > @mean_level").head()
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 34                     none          97             87             82
# 104               completed          98             86             90
# 114               completed          99            100            100
# 121               completed          91             89             92
# 149               completed         100            100             93

# %%
student_perfomance.filter(like = "score").head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
student_perfomance.query("math_score > @mean_level").filter(like = "0"  ,axis = 0)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 104    male        group C                some college      standard
# 306    male        group E                some college      standard
# 501  female        group B          associate's degree      standard
# 503  female        group E          associate's degree      standard
# 710    male        group C                some college      standard
# 903  female        group D           bachelor's degree  free/reduced
# 950    male        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 104               completed          98             86             90
# 306               completed          99             87             81
# 501               completed          94             87             92
# 503               completed          95             89             92
# ...
