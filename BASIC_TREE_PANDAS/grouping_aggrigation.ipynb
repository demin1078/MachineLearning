# %%
import numpy as np
import pandas as pd

student_perfomance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

student_perfomance = student_perfomance.rename(columns = {
    "math score":"math_score",
    "reading score":"reading_score",
    "writing score":"writing_score"
})
student_perfomance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_perfomance.groupby("race/ethnicity", as_index=False).aggregate({"lunch":"max","math_score":"mean"})a
# Out:
#   race/ethnicity     lunch  math_score
# 0        group A  standard   61.629213
# 1        group B  standard   63.452632
# 2        group C  standard   64.463950
# 3        group D  standard   67.362595
# 4        group E  standard   73.821429

# %%
student_perfomance.groupby(["gender","race/ethnicity"]).aggregate({"lunch":"max","math_score":"mean"})
# Out:
#                           lunch  math_score
# gender race/ethnicity
# female group A         standard   58.527778
#        group B         standard   61.403846
#        group C         standard   62.033333
#        group D         standard   65.248062
#        group E         standard   70.811594
# male   group A         standard   63.735849
#        group B         standard   65.930233
#        group C         standard   67.611511
#        group D         standard   69.413534
#        group E         standard   76.746479

# %%
#Choose five the best boys and girls in Math
student_perfomance.sort_values(['gender','math_score'], ascending=[True,False]).groupby('gender').head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
#
#     test preparation course  math_score  reading score  writing score
# 451                    none         100             92             97
# ...

# %%
student_perfomance.groupby('gender')[['math_score']].mean()
student_perfomance.groupby('gender')[['math_score']].mean()
# Out:
#         math_score
# gender
# female   63.633205
# male     68.728216

# %%
# Adding and deleting of columns 
student_perfomance['total_score'] = student_perfomance.math_score + student_perfomance.writing_score +student_perfomance.reading_score

# %%
student_perfomance = student_perfomance.assign(total_score_log = np.log(student_perfomance.total_score))

# %%
student_perfomance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
student_perfomance = student_perfomance.drop(['total_score','lunch'],axis = 1)

# %%
student_perfomance.head()
#End of theory !!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    gender race/ethnicity parental level of education test preparation course  \
# 0  female        group B           bachelor's degree                    none
# 1  female        group C                some college               completed
# 2  female        group B             master's degree                    none
# 3    male        group A          associate's degree                    none
# 4    male        group C                some college                    none
#
#    math_score  reading_score  writing_score  total_score_log
# 0          72             72             74         5.384495
# 1          69             90             88         5.509388
# 2          90             95             93         5.627621
# 3          47             57             44         4.997212
# 4          76             78             75         5.433722

# %%
#dota legs

# %%
dota_db = pd.read_csv("dota_hero_stats.csv")
dota_db.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota_db.groupby("legs").count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
dota_db.groupby(["attack_type",'primary_attr'])['id'].count()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# Name: id, dtype: int64

# %%
#lupa and Pupa
df_lupa = pd.read_csv("accountancy.csv")
df_lupa.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
df_lupa.groupby(["Type", "Executor"])['Salary'].mean()
# Out:
# Type  Executor
# A     Loopa        58.000000
#       Pupa        160.833333
# B     Loopa       145.166667
#       Pupa         77.000000
# C     Loopa       154.333333
#       Pupa         74.500000
# D     Loopa       137.714286
#       Pupa        146.500000
# E     Loopa       164.000000
#       Pupa        131.200000
# F     Loopa       238.000000
#       Pupa        136.250000
# Name: Salary, dtype: float64

# %%
df_seaweed = pd.read_csv("algae.csv")
df_seaweed.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
df_seaweed.groupby('genus').agg(['min', 'mean', 'max']).loc['Fucus','alanin']
# Out:
# min     0.346431
# mean    3.566411
# max     6.641303
# Name: Fucus, dtype: float64

# %%
df_seaweed.groupby("group")['species'].count()
# Out:
# group
# brown    6
# green    3
# red      1
# Name: species, dtype: int64

# %%
df_seaweed.groupby('group').agg(np.ptp).loc[:,'glucose']
# Out:
# group
# brown    3.740495
# green    1.026753
# red      0.000000
# Name: glucose, dtype: float64

# %%
df_seaweed.groupby('group').agg("var")
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# group
# brown  5.459098  7.220351  5.468942  1.767756    4.385233
# green  2.672626  7.059917  3.950113  0.266265    0.540388
# red         NaN       NaN       NaN       NaN         NaN
