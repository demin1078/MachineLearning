# %%
import pandas as pd
import numpy as np
df = pd.read_csv('operative_information.csv')

# %%
# %%timeit
df.apply('mean')
# Out:
# 248 µs ± 912 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
df.mean(axis=0)
# Out:
# 212 µs ± 393 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
df.apply(np.mean)
# Out:
# 421 µs ± 3.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
df.describe().loc['mean']
# Out:
# 5.66 ms ± 43.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
