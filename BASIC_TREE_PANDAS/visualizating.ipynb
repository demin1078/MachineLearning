# %%
import numpy as np
import pandas as pd

# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns


student_perfomance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

student_perfomance = student_perfomance.rename(columns = {
    "math score":"math_score",
    "reading score":"reading_score",
    "writing score":"writing_score"
})
student_perfomance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_perfomance.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
student_perfomance.plot.scatter(x = "math_score",y = "reading_score")
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x = "math_score",y = "reading_score",hue = "gender", data = student_perfomance, fit_reg=False)
ax.set_xlabels("Math")
ax.set_ylabels("Reading")

# %%
df = pd.read_csv("income.csv")

# %%
df.plot(kind='line')
sns.lineplot(data=df)
df.plot()
df['income'].plot()
df.income.plot()
sns.lineplot(x=df.index, y=df.income)

plt.plot(df.index, df.income)

# %%
df = pd.read_csv("dataset_209770_6.txt",sep = " ")
df.plot.scatter(x = "x",y = "y")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df = pd.read_csv("genome_matrix.csv")
df
g = sns.heatmap(data = df.iloc[:,1:], cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df = pd.read_csv("dota_hero_stats.csv")
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
sns.histplot(x = [i.count(",")+1 for i in df['roles']], data = df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df = pd.read_csv("iris.csv")
sns.kdeplot(data=df.iloc[:,1:])
sns.displot(data = df.iloc[:,1:], kde_kws={ "label":column})

# %%
import random
colors = [0,0,0]
for column in df.iloc[:,1:]:
    sns.histplot(data = df[column],color = f'#{colors[0]}{colors[1]}{colors[2]}')
   
    colors[0] = random.randint(10,99)
    colors[1] = random.randint(10,99)
    colors[2] = random.randint(10,99)
    
plt.legend(labels = [i for i in df.iloc[:,1:]])

# %%
sns.violinplot(data = df['petal length'])
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data = df.iloc[:,1:])

# %%
df.iloc[:,1:].corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
my_data = pd.DataFrame([["first",1],["second",2],["thirth",3],["fourth",4]], columns = ["type", "value"])
# Out:
#      type  value
# 0   first      1
# 1  second      2
# 2  thirth      3
# 3  fourth      4

# %%
my_stat = pd.read_csv("my_stat.csv")
subset_1 = my_stat.query('V1 > 0 & V3 == "A"')
subset_2 = my_stat[(my_stat['V2'] > 100) & (my_stat['V4'] >= 10)]
subset_2
# Out:
# Empty DataFrame
# Columns: [V1, V2, V3, V4]
# Index: []

# %%
import numpy as np
my_stat['V5'] = my_stat['V1']+ my_stat['V4']
my_stat['V6'] = my_stat.agg({"V2":np.log})
my_stat
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# ..   ..   ... ..  ...  ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442
# 497  -1  11.0  B  2.0  1.0  2.397895
# 498   1  11.0  A  2.0  3.0  2.397895
# 499   0   8.0  B  1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
my_stat = my_stat.rename(columns = {"V1":"session_value","V2":"group","V3":"time","V4":"n_users"})
my_stat
# Out:
#      session_value  group time  n_users   V5        V6
# 0                2   13.0    B      1.0  3.0  2.564949
# 1               -1    7.0    B      1.0  0.0  1.945910
# 2                0   11.0    A      0.0  0.0  2.397895
# 3                2   11.0    A      2.0  4.0  2.397895
# 4                0   10.0    B     -1.0 -1.0  2.302585
# ..             ...    ...  ...      ...  ...       ...
# 495              1    8.0    A     -1.0  0.0  2.079442
# 496              3    8.0    A      1.0  4.0  2.079442
# 497             -1   11.0    B      2.0  1.0  2.397895
# 498              1   11.0    A      2.0  3.0  2.397895
# 499              0    8.0    B      1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
my_stat = pd.read_csv("my_stat_1_гз.csv")
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
my_stat['session_value'] = my_stat['session_value'].fillna(0)
med = my_stat[my_stat['n_users'] > 0]['n_users'].median()
my_stat.loc[my_stat.n_users < 0,"n_users"] = med
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A        5
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B        5
# 9            0.0     9     A        5

# %%
mean_session_value_data = my_stat.groupby(["group"], as_index=False).agg({"session_value":"mean"}).\
rename(columns={"session_value":"mean_session_value"})
mean_session_value_data
# Out:
#   group  mean_session_value
# 0     A                 0.8
# 1     B                 0.8
